# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('train.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print('max of SalePrice : {}'.format(df['SalePrice'].max()))
print('median of SalePrice : {}'.format(df['SalePrice'].median()))
# Out:
# max of SalePrice : 755000
# median of SalePrice : 163000.0

# %% [markdown]
# ## Data Analysis

# %%
# check if there is non-value in the dataset or not

# %%
missing_data = pd.DataFrame(columns = ['missing values'])
for feature in df.columns:
    no_missing = df[feature].isnull().sum()
    if no_missing!= 0:
        missing_data.loc[feature] = [round(no_missing*100/len(df[feature]), 4)]
missing_data
# Out:
#               missing values
# LotFrontage          17.7397
# Alley                93.7671
# MasVnrType            0.5479
# MasVnrArea            0.5479
# BsmtQual              2.5342
# BsmtCond              2.5342
# BsmtExposure          2.6027
# BsmtFinType1          2.5342
# BsmtFinType2          2.6027
# Electrical            0.0685
# FireplaceQu          47.2603
# GarageType            5.5479
# GarageYrBlt           5.5479
# GarageFinish          5.5479
# GarageQual            5.5479
# GarageCond            5.5479
# PoolQC               99.5205
# Fence                80.7534
# MiscFeature          96.3014

# %% [markdown]
# Alley	 93.7671% missing value
# PoolQC	99.5205% missing value
# Fence	80.7534% missing value
# MiscFeature	96.3014% missing value
# that's too much missing values.
# So, either I can drop that colunms or can conclude something from it.

# %%
# let's check if we are able to draw some meaningfull observation from these missing data.
# This we can do by graph visulization.
df_temp = df.copy()
for feature in missing_data.index:
    df_temp[feature] = np.where(df_temp[feature].isnull(), 1, 0)
    df_temp.groupby(feature)['SalePrice'].median().plot.bar(color=['r','y'])
    plt.title(feature)
    plt.show()

# %% [markdown]
# clearly shows there are some relationship between salesprice and missing values and we will fill some meaningfull values into it in feature Engineering part.

# %%
# let's deal with all year column

# %% [markdown]
# ### Analysis of Temporal Variables(Eg: Datetime Variables)

# %%
year_feature = [feature for feature in df.columns if 'Year' in feature or 'Yr' in feature ]

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_feature:
    print(feature, df[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
# check whether there is any relationship between Yearsold and salesprice
df.groupby('YrSold')['SalePrice'].median().plot()
# Out:
# <AxesSubplot:xlabel='YrSold'>

# %% [markdown]
# It is clearly drawn that as year passing salesprice decreases.
# That is an absurd because generally price of a house increses with the time.

# %%
# let'analyse salesprice with time new item to add in the house.
df_temp = df.copy()
for feature in year_feature:
    if feature != 'YrSold':
        df_temp[feature] = df_temp['YrSold'] - df_temp[feature]
        df_temp.groupby(feature)['SalePrice'].median().plot()
        plt.title(feature)
        plt.show()

# %% [markdown]
# It is clear from the above visuals that as things get older, their price will get decrease. However, dataset has some unexpected rise in price which is probably an outlier.

# %% [markdown]
# ### Analysis of Numeric Feature

# %%
# divide numerical and categorical feature and show their distribution.
num_col = [feature for feature in df.columns if pd.api.types.is_numeric_dtype(df[feature]) and feature!= 'Id' and feature!= 'SalePrice']

# %%
df[num_col]
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %% [markdown]
# Numeric feature
# + continuous feature
# + discrete feature

# %%
df[num_col].nunique()
# Out:
# MSSubClass         15
# LotFrontage       110
# LotArea          1073
# OverallQual        10
# OverallCond         9
# YearBuilt         112
# YearRemodAdd       61
# MasVnrArea        327
# BsmtFinSF1        637
# BsmtFinSF2        144
# BsmtUnfSF         780
# TotalBsmtSF       721
# 1stFlrSF          753
# 2ndFlrSF          417
# LowQualFinSF       24
# GrLivArea         861
# BsmtFullBath        4
# BsmtHalfBath        3
# FullBath            4
# HalfBath            3
# BedroomAbvGr        8
# KitchenAbvGr        4
# TotRmsAbvGrd       12
# Fireplaces          4
# GarageYrBlt        97
# GarageCars          5
# GarageArea        441
# WoodDeckSF        274
# OpenPorchSF       202
# EnclosedPorch     120
# 3SsnPorch          20
# ScreenPorch        76
# PoolArea            8
# MiscVal            21
# MoSold             12
# YrSold              5
# dtype: int64

# %%
df_temp = df.copy()
for feature in num_col:
    if df[feature].isnull().sum() !=0:
        df_temp[feature] = np.where(df_temp[feature].isnull(), 1, 0)
        df_temp.groupby(feature)['SalePrice'].median().plot.bar()
        plt.title(feature)
        plt.show()

# %%
list1 = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
# segregate feature having less than 25 unique values into discrete feature while rest of them into continuous feature.

# %%
disc_feature = [feature for feature in num_col if df[feature].nunique()<25 and feature not in year_feature+['Id']]
print("Discrete Variables Count: {}".format(len(disc_feature)))
# Out:
# Discrete Variables Count: 17

# %%
df[disc_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
# let's find out the relationship between them and saleprice
for feature in disc_feature:
    df.groupby(df[feature])['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# clearly shows relationship between variable and saleprice.

# %%
cont_feature = [feature for feature in num_col if feature not in disc_feature+year_feature+['Id']]
print('no. of continuous variable is {}'.format(len(cont_feature)))
# Out:
# no. of continuous variable is 15

# %%
# let's analyse the relationship between salesprice and these variables.
for feature in cont_feature:
    df[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('frequency')
    plt.show()

# %% [markdown]
# Looks like most of the variable is right skewed. Some of them is normally distributed.

# %%
# now we have to transform it and then visaulise
for feature in cont_feature:
    data = df.copy() # we can't modify in the original dataset as we are here for EDA not feature Engineering.
    if 0 not in df[feature].unique():
        data[feature]= np.log(data[feature])
        data['SalePrice']= np.log(data['SalePrice'])
        data[feature].hist(bins=25)
        plt.xlabel(feature)
        plt.ylabel('frequency')
        plt.show()

# %%
for feature in cont_feature:
    data = df.copy() # we can't modify in the original dataset as we are here for EDA not feature Engineering.
    if 0 not in df[feature].unique():
        data[feature]= np.log(data[feature])
        data['SalePrice']= np.log(data['SalePrice'])
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature+' vs '+'SalePrice')
        plt.show()

# %% [markdown]
# ###  Analysis of Outlier

# %%
for feature in cont_feature:
    data = df.copy() # we can't modify in the original dataset as we are here for EDA not feature Engineering.
    if 0 not in df[feature].unique():
        data[feature]= np.log(data[feature])
        data.boxplot(column=feature)
        plt.show()

# %% [markdown]
# Shows that there are so many outlier in the dataset.

# %% [markdown]
# ### Analysis of Categorical data

# %%
cat_feature = [feature for feature in df.columns if df[feature].dtypes=='O']
cat_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
print('number of categorical data : {}'.format(len(cat_feature)))
# Out:
# number of categorical data : 43

# %%
df[cat_feature]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
df[cat_feature].nunique()
# Out:
# MSZoning          5
# Street            2
# Alley             2
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        8
# BldgType          5
# HouseStyle        8
# RoofStyle         6
# RoofMatl          8
# Exterior1st      15
# Exterior2nd      16
# MasVnrType        4
# ExterQual         4
# ExterCond         5
# Foundation        6
# BsmtQual          4
# BsmtCond          4
# BsmtExposure      4
# BsmtFinType1      6
# BsmtFinType2      6
# Heating           6
# HeatingQC         5
# CentralAir        2
# Electrical        5
# KitchenQual       4
# Functional        7
# FireplaceQu       5
# GarageType        6
# GarageFinish      3
# GarageQual        5
# GarageCond        5
# PavedDrive        3
# PoolQC            3
# Fence             4
# MiscFeature       4
# SaleType          9
# SaleCondition     6
# dtype: int64

# %%
# Analyse the relationship between them and SalePrice
for feature in cat_feature:
    df.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature+' vs SalePrice')
    plt.show()

# %% [markdown]
# # Feature Engineering

# %%
## Always remember there way always be a chance of data leakage so we need to split the data first and t
# split th data and then try Feature Engineering
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df, df['SalePrice'],test_size=0.1,random_state=0)

# %%
X_train.shape, X_train.shape
# Out:
# ((1314, 81), (1314, 81))

# %% [markdown]
# #### Handling of Missing values

# %%
missing_data
# Out:
#               missing values
# LotFrontage          17.7397
# Alley                93.7671
# MasVnrType            0.5479
# MasVnrArea            0.5479
# BsmtQual              2.5342
# BsmtCond              2.5342
# BsmtExposure          2.6027
# BsmtFinType1          2.5342
# BsmtFinType2          2.6027
# Electrical            0.0685
# FireplaceQu          47.2603
# GarageType            5.5479
# GarageYrBlt           5.5479
# GarageFinish          5.5479
# GarageQual            5.5479
# GarageCond            5.5479
# PoolQC               99.5205
# Fence                80.7534
# MiscFeature          96.3014

# %%
## first handle missing value of categorical feature.
for feature in cat_feature:
    df[feature].fillna('missing', inplace=True)

# %%
df.head(50)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  missing      Reg
# 1    2          20       RL         80.0     9600   Pave  missing      Reg
# 2    3          60       RL         68.0    11250   Pave  missing      IR1
# 3    4          70       RL         60.0     9550   Pave  missing      IR1
# 4    5          60       RL         84.0    14260   Pave  missing      IR1
# 5    6          50       RL         85.0    14115   Pave  missing      IR1
# 6    7          20       RL         75.0    10084   Pave  missing      Reg
# 7    8          60       RL          NaN    10382   Pave  missing      IR1
# 8    9          50       RM         51.0     6120   Pave  missing      Reg
# 9   10         190       RL         50.0     7420   Pave  missing      Reg
# 10  11          20       RL         70.0    11200   Pave  missing      Reg
# ...

# %%
df[cat_feature].isnull().sum()
# Out:
# MSZoning         0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# KitchenQual      0
# Functional       0
# FireplaceQu      0
# GarageType       0
# GarageFinish     0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
df[num_col].isnull().sum()
# Out:
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
## handle of missing data of numerical feature
for feature in list1:
        df[feature+'_nan'] = np.where(df[feature].isnull(), 1, 0)
        df[feature].fillna(df[feature].median(), inplace=True)

# %%
for feature in [feature for feature in num_col if feature not in list1]:
    df[feature]= np.where(df[feature].isnull(), df[feature].mode(), df[feature])

# %%
df[num_col].isnull().sum()
# Out:
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
for feature in year_feature:
    if feature != 'YrSold':
        df[feature] = df['YrSold']-df[feature]

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  missing      Reg
# 1   2          20       RL         80.0     9600   Pave  missing      Reg
# 2   3          60       RL         68.0    11250   Pave  missing      IR1
# 3   4          70       RL         60.0     9550   Pave  missing      IR1
# 4   5          60       RL         84.0    14260   Pave  missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
cont_feature
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch']

# %% [markdown]
# #### handling of numerical feature

# %%
for feature in ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']:
        df[feature]= np.log(df[feature])

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ##### Handling of Categorical feature

# %%
for feature in cat_feature:
    temp=df.groupby(feature)['SalePrice'].count()/len(df)
    temp_index = temp[temp>0.01].index
    df[feature] = np.where(df[feature].isin(temp_index), df[feature], 'Rare_val')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl     Rare_val      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
for feature in cat_feature:
    labels_ordered = df.groupby(feature)['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df[feature]=df[feature].map(labels_ordered)

# %%
df.head(50)
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    1          60         3     4.174387  9.041922       1      2         0
# 1    2          20         3     4.382027  9.169518       1      2         0
# 2    3          60         3     4.219508  9.328123       1      2         1
# 3    4          70         3     4.094345  9.164296       1      2         1
# 4    5          60         3     4.430817  9.565214       1      2         1
# 5    6          50         3     4.442651  9.554993       1      2         1
# 6    7          20         3     4.317488  9.218705       1      2         0
# 7    8          60         3     4.234107  9.247829       1      2         1
# 8    9          50         1     3.931826  8.719317       1      2         0
# 9   10         190         3     3.912023  8.911934       1      2         0
# 10  11          20         3     4.248495  9.323669       1      2         0
# ...

# %% [markdown]
# # Feature Scaling

# %%
feature_scale=[feature for feature in df.columns if feature not in ['Id','SalePrice']]

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(df[feature_scale])
# Out:
# array([[0.23529412, 0.75      , 0.41820812, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.49506375, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.29411765, 0.75      , 0.42385922, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.47117546, ..., 0.        , 0.        ,
#         0.        ]])

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([df[['Id']],
                    pd.DataFrame(scaler.transform(df[feature_scale]), columns=feature_scale), df[['SalePrice']]],
                    axis=1)

# %%
data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1    0.235294      0.75     0.418208  0.366344     1.0    1.0  0.000000
# 1   2    0.000000      0.75     0.495064  0.391317     1.0    1.0  0.000000
# 2   3    0.235294      0.75     0.434909  0.422359     1.0    1.0  0.333333
# 3   4    0.294118      0.75     0.388581  0.390295     1.0    1.0  0.333333
# 4   5    0.235294      0.75     0.513123  0.468761     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.333333        1.0       0.00        0.0      0.636364         0.4
# 1     0.333333        1.0       0.50        0.0      0.500000         0.2
# 2     0.333333        1.0       0.00        0.0      0.636364         0.4
# 3     0.333333        1.0       0.25        0.0      0.727273         0.4
# 4     0.333333        1.0       0.50        0.0      1.000000         0.4
#
# ...

# %%
data.to_csv('X_train.csv', index=False)

# %% [markdown]
# # Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
dataset=pd.read_csv('X_train.csv')
dataset.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1    0.235294      0.75     0.418208  0.366344     1.0    1.0  0.000000
# 1   2    0.000000      0.75     0.495064  0.391317     1.0    1.0  0.000000
# 2   3    0.235294      0.75     0.434909  0.422359     1.0    1.0  0.333333
# 3   4    0.294118      0.75     0.388581  0.390295     1.0    1.0  0.333333
# 4   5    0.235294      0.75     0.513123  0.468761     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.333333        1.0       0.00        0.0      0.636364         0.4
# 1     0.333333        1.0       0.50        0.0      0.500000         0.2
# 2     0.333333        1.0       0.00        0.0      0.636364         0.4
# 3     0.333333        1.0       0.25        0.0      0.727273         0.4
# 4     0.333333        1.0       0.50        0.0      1.000000         0.4
#
# ...

# %%
## Capture the dependent feature
y_train=dataset[['SalePrice']]

# %%
## drop dependent feature from dataset
X_train=dataset.drop(['Id','SalePrice'],axis=1)

# %%
### Apply Feature Selection
# first, I specify the Lasso Regression model, and I
# select a suitable alpha (equivalent of penalty).
# The bigger the alpha the less features that will be selected.

# Then I use the selectFromModel object from sklearn, which
# will select the features which coefficients are non-zero

feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=0)) # remember to set the seed, the random state in this function
feature_sel_model.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False])

# %%
# let's print the number of total and selected features

# this is how we can make a list of the selected features
selected_feat = X_train.columns[(feature_sel_model.get_support())]

# let's print some stats
print('total features: {}'.format((X_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
# Out:
# total features: 82
# selected features: 21

# %%
selected_feat
# Out:
# Index(['MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual', 'YearRemodAdd',
#        'RoofStyle', 'BsmtQual', 'BsmtExposure', 'HeatingQC', 'CentralAir',
#        '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'KitchenQual', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'PavedDrive',
#        'SaleCondition'],
#       dtype='object')

# %%
X_train=X_train[selected_feat]

# %%
X_train.head()
# Out:
#    MSSubClass  MSZoning  Neighborhood  OverallQual  YearRemodAdd  RoofStyle  \
# 0    0.235294      0.75      0.636364     0.666667      0.098361        0.0
# 1    0.000000      0.75      0.500000     0.555556      0.524590        0.0
# 2    0.235294      0.75      0.636364     0.666667      0.114754        0.0
# 3    0.294118      0.75      0.727273     0.666667      0.606557        0.0
# 4    0.235294      0.75      1.000000     0.777778      0.147541        0.0
#
#    BsmtQual  BsmtExposure  HeatingQC  CentralAir  1stFlrSF  GrLivArea  \
# 0      0.75          0.25       1.00         1.0  0.356155   0.577712
# 1      0.75          1.00       1.00         1.0  0.503056   0.470245
# 2      0.75          0.50       1.00         1.0  0.383441   0.593095
# 3      0.50          0.25       0.75         1.0  0.399941   0.579157
# 4      0.75          0.75       1.00         1.0  0.466237   0.666523
#
#    BsmtFullBath  KitchenQual  Fireplaces  FireplaceQu  GarageType  \
# ...

# %%
X_train.shape
# Out:
# (1460, 21)
